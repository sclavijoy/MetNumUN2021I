# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select NVDA minute resolution data and set it to Raw normalization mode
        self.ctrn = self.AddEquity("CTRN", Resolution.Minute)
        self.ctrn.SetDataNormalizationMode(DataNormalizationMode.Raw)        

    def OnData(self, data):
        
        if not self.Portfolio.Invested:
            self.MarketOrder("CTRN", 300)            
            
            #Debug the Average Price
            self.Debug(str(self.Portfolio["CTRN"].AveragePrice))

# %% [markdown]
# ![CTRN.PNG](data:image/png;base64,...)

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select NVDA minute resolution data and set it to Raw normalization mode
        self.ctrn = self.AddEquity("CTRN", Resolution.Minute)
        self.ctrn.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        #self.bsx = self.AddEquity("BSX", Resolution.Minute)
        #self.bsx.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        if not self.Portfolio.Invested:
            self.MarketOrder("CTRN", 300)
            #self.MarketOrder("BSX", 300)
            
            #Debug the Average Price
            self.Debug(str(self.Portfolio["CTRN"].AveragePrice))
            #self.Debug(str(self.Portfolio["BSX"].AveragePrice))

# %% [markdown]
# ![CTRN x BSX.PNG](data:image/png;base64,...)

# %%
# two year time period
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        # Select stocks and add in DataNormalizationMode = Raw
        self.ctrn = self.AddEquity("CTRN", Resolution.Minute)
        self.ctrn.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.bsx = self.AddEquity("BSX", Resolution.Minute)
        self.bsx.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.indu = self.AddEquity("INDU", Resolution.Minute)
        self.indu.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.bsx.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.mrna = self.AddEquity("MRNA", Resolution.Minute)
        
        self.mrna = self.AddEquity("BABA", Resolution.Minute)
        self.mrna.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("CTRN", 300)
            self.MarketOrder("BSX", 300)
            self.MarketOrder("INDU", 300)
            self.MarketOrder("MRNA", 300)
            self.MarketOrder("BABA", 300)
            
            #Debug the Average Price
            self.Debug(str(self.Portfolio["CTRN"].AveragePrice))
            self.Debug(str(self.Portfolio["BSX"].AveragePrice))
            self.Debug(str(self.Portfolio["INDU"].AveragePrice))
            self.Debug(str(self.Portfolio["MRNA"].AveragePrice))
            self.Debug(str(self.Portfolio["BABA"].AveragePrice))

# %% [markdown]
# ![towyears.PNG](data:image/png;base64,...)

# %%
# six months time period
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 7, 1)
        self.SetEndDate(2021, 1, 1)

        # Select stocks and add in DataNormalizationMode = Raw
        self.ctrn = self.AddEquity("CTRN", Resolution.Minute)
        self.ctrn.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.bsx = self.AddEquity("BSX", Resolution.Minute)
        self.bsx.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.indu = self.AddEquity("INDU", Resolution.Minute)
        self.indu.SetDataNormalizationMode(DataNormalizationMode.Raw)
        
        self.bsx.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.mrna = self.AddEquity("MRNA", Resolution.Minute)
        
        self.mrna = self.AddEquity("BABA", Resolution.Minute)
        self.mrna.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("CTRN", 300)
            self.MarketOrder("BSX", 300)
            self.MarketOrder("INDU", 300)
            self.MarketOrder("MRNA", 300)
            self.MarketOrder("BABA", 300)
            
            #Debug the Average Price
            self.Debug(str(self.Portfolio["CTRN"].AveragePrice))
            self.Debug(str(self.Portfolio["BSX"].AveragePrice))
            self.Debug(str(self.Portfolio["INDU"].AveragePrice))
            self.Debug(str(self.Portfolio["MRNA"].AveragePrice))
            self.Debug(str(self.Portfolio["BABA"].AveragePrice))

# %% [markdown]
# ![sixmonths.PNG](data:image/png;base64,...)
